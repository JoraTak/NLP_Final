# %%
from __future__ import absolute_import
from __future__ import print_function
from __future__ import division

import json, os, re, shutil, sys, time
from importlib import reload
import collections, itertools
import unittest
from IPython.display import display, HTML

# NLTK for NLP utils and corpora
import nltk

# Pandas NumPy and TensorFlow
import pandas as pd
import numpy as np
import tensorflow as tf
assert(tf.__version__.startswith("1."))

# Helper libraries
from utils import utils_proj, vocabulary

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import lstm; reload(lstm)
import matplotlib.pyplot as plt

% matplotlib inline

# %%
def load_train():
    names = ['timestamp','date','query','handle','message']
    df = pd.read_csv('../sentiment140.csv',encoding='Latin1',names=names)
    df['sentiment'] = df.index
    #Instead of positive being 4 make positive 1
    df.loc[df['sentiment'] == 4,'sentiment']=1
    
    return df
    
def build_vocab(x_data):
    
    #build the vocab
    x_data = [i.split() for i in x_data]
    flat_list = [item for sublist in x_data for item in sublist]
    vocab = utils_proj.build_vocab(flat_list)
    
    return x_data,vocab
    
def longest_tweet():
    #Determine the length of the longest tweet
    max_val=0
    for i in x_data:
        if len(i) > max_val:
            max_val = len(i)
    print('Longest tweet :',max_val,'tokens')
    
def preprocess(x_data,vocab,max_time=70):
    #canonicalize sentences, convert to ids,zero pad to consistant length of max_time
    
    max_time=max_time
    
    x_ids = []
    for tweet in x_data:
        temp = utils_proj.preprocess_sentences([tweet],vocab)
        x_ids.append(
            np.pad(utils_proj.preprocess_sentences([tweet],vocab),(max_time-2-len(tweet),0),'constant').tolist()) 
    
    return x_ids


def train_test_dev(x,y,train_pct=.8,test_pct=.1,random_state=1):
    """Split into train dev and test"""
    
    X_train, X_test, y_train, y_test = (
        train_test_split(x, y, test_size=round(1-train_pct,1), random_state=random_state))
    #split test into dev and test
    X_dev, X_test, y_dev, y_test = (
        train_test_split(X_test, y_test, test_size=test_pct/(1-train_pct), random_state=random_state))
    
    
    return np.asarray(X_train),np.asarray(X_dev),np.asarray(X_test),np.asarray(y_train),np.asarray(y_dev),np.asarray(y_test)

# %%
#Commence the preprocessing steps
df = load_train()

print(df.head())

#Extract x and y columns
x_data = df['message'].tolist()
y_data = df['sentiment'].tolist()
    
x_data,vocab = build_vocab(x_data)

longest_tweet()
max_time=70
x_ids = preprocess(x_data,vocab)

X_train,X_dev,X_test,y_train,y_dev,y_test = train_test_dev(x_ids,y_data,.67,0)
# Out:
#     timestamp                          date     query           handle  \
# 0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                              message  sentiment
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...          0
# 0  is upset that he can't update his Facebook by ...          0
# 0  @Kenichan I dived many times for the ball. Man...          0
# 0    my whole body feels itchy and like its on fire           0
# 0  @nationwideclass no, it's not behaving at all....          0
# Vocabulary: 10,000 types
# Longest tweet : 64 tokens

# %%
print(len(X_dev))
print(len(X_test))
# Out:
# 480000
# 0

# %%
def run_epoch(lm, session, batch_iterator,
              train=False, verbose=False,
              tick_s=60, learning_rate=None):
    
    assert(learning_rate is not None)
    start_time = time.time()
    tick_time = start_time  # for showing status
    total_cost = 0.0  # total cost, summed over all words
    total_batches = 0
    total_tweets = 0
    
    val_acc = []
    y_true = []
    y_pred = []
    
    train_op = lm.optimizer_
    use_dropout = True
    loss = lm.train_loss_

    for i, (w, y) in enumerate(batch_iterator):
       
        y_true.append(y)
        if i == 0:
            h = session.run(lm.initial_h_, {lm.input_w_: w})
        feed_dict = {
            lm.input_w_: w,
            lm.target_y_: y,
            lm.initial_h_: h,
            lm.learning_rate_: learning_rate,

        }
        ops = [loss, lm.final_h_, train_op,lm.accuracy_,lm.predictions_]        

        cost,h,_,batch_acc,preds = session.run(ops,feed_dict=feed_dict)
        
        y_pred.append(preds)
        val_acc.append(batch_acc)
        total_cost += cost
        total_batches = i + 1
        total_tweets += w.shape[0]  

        if verbose and (time.time() - tick_time >= tick_s):
            avg_cost = total_cost / total_batches
            avg_tps = total_tweets / (time.time() - start_time)
            print("[batch {:d}]: seen {:d} tweets at {:.1f} tps, cost = {:.3f}".format(
                i, total_tweets, avg_tps, avg_cost))
            tick_time = time.time()  # reset time ticker
    
    if train:
        return total_cost / total_batches,val_acc
    else:
        return total_cost / total_batches, val_acc,y_true,y_pred

# %%
# Training parameters
max_time = max_time
batch_size = 1000
learning_rate = 0.01
num_epochs = 4
TF_GRAPHDIR = "~/w266_final_project/tmp/w266/a3_graph"

# Model parameters
model_params = dict(V=vocab.size, 
                    H=50, 
                    softmax_ns=200,
                    num_layers=2,
                    num_classes=1)

#TF_GRAPHDIR = "/tmp/w266/a3_graph"
summary_writer = tf.summary.FileWriter(TF_GRAPHDIR, lm.graph)
TF_SAVEDIR = "~/w266_final_project/tmp/w266/a3_model"

checkpoint_filename = os.path.join(TF_SAVEDIR, "rnnlm")
trained_filename = os.path.join(TF_SAVEDIR, "rnnlm_trained")

# %%
#Run Model Training
reload(lstm)
reload(utils_proj)
print_interval = 5

lm = lstm.RNNLM(**model_params)
lm.BuildCoreGraph()
lm.BuildTrainGraph()

# Explicitly add global initializer and variable saver to LM graph
with lm.graph.as_default():
    initializer = tf.global_variables_initializer()
    saver = tf.train.Saver()
    
# Clear old log directory
shutil.rmtree(TF_SAVEDIR, ignore_errors=True)
if not os.path.isdir(TF_SAVEDIR):
    os.makedirs(TF_SAVEDIR)

with tf.Session(graph=lm.graph) as session:
    # Seed RNG for repeatability
    tf.set_random_seed(42)

    session.run(initializer)
    
    
    for epoch in range(1,num_epochs+1):
        t0_epoch = time.time()
        bi = utils_proj.rnnlm_batch_generator(X_train, batch_size, max_time,y_train)

        cost,val_acc = run_epoch(lm, session, bi,True,
                  True,1.0,learning_rate)
        
        print("[epoch {:d}] Completed in {:s}".format(epoch, utils_proj.pretty_timedelta(since=t0_epoch)))
    
        # Save a checkpoint 
        saver.save(session, checkpoint_filename, global_step=epoch)
   
    #Save final model
    saver.save(session, trained_filename)
# Out:
# [batch 1]: seen 2000 tweets at 1420.8 tps, cost = 0.248
# [batch 3]: seen 4000 tweets at 1517.2 tps, cost = 0.248
# [batch 5]: seen 6000 tweets at 1560.0 tps, cost = 0.246
# [batch 7]: seen 8000 tweets at 1585.3 tps, cost = 0.244
# [batch 9]: seen 10000 tweets at 1601.3 tps, cost = 0.242
# [batch 11]: seen 12000 tweets at 1608.3 tps, cost = 0.240
# [batch 13]: seen 14000 tweets at 1614.3 tps, cost = 0.236
# [batch 15]: seen 16000 tweets at 1624.0 tps, cost = 0.235
# [batch 17]: seen 18000 tweets at 1630.9 tps, cost = 0.233
# [batch 19]: seen 20000 tweets at 1634.6 tps, cost = 0.231
# [batch 21]: seen 22000 tweets at 1636.2 tps, cost = 0.229
# [batch 23]: seen 24000 tweets at 1636.1 tps, cost = 0.227
# [batch 25]: seen 26000 tweets at 1634.7 tps, cost = 0.224
# [batch 27]: seen 28000 tweets at 1635.9 tps, cost = 0.223
# [batch 29]: seen 30000 tweets at 1634.5 tps, cost = 0.221
# [batch 31]: seen 32000 tweets at 1626.2 tps, cost = 0.219
# [batch 33]: seen 34000 tweets at 1618.2 tps, cost = 0.217
# [batch 35]: seen 36000 tweets at 1611.5 tps, cost = 0.215
# [batch 37]: seen 38000 tweets at 1607.2 tps, cost = 0.213
# [batch 39]: seen 40000 tweets at 1598.9 tps, cost = 0.212
# [batch 41]: seen 42000 tweets at 1594.3 tps, cost = 0.210
# [batch 43]: seen 44000 tweets at 1589.0 tps, cost = 0.208
# [batch 45]: seen 46000 tweets at 1588.1 tps, cost = 0.207
# [batch 47]: seen 48000 tweets at 1590.5 tps, cost = 0.205
# [batch 49]: seen 50000 tweets at 1592.9 tps, cost = 0.204
# [batch 51]: seen 52000 tweets at 1594.2 tps, cost = 0.202
# [batch 53]: seen 54000 tweets at 1595.7 tps, cost = 0.201
# [batch 55]: seen 56000 tweets at 1596.9 tps, cost = 0.200
# [batch 57]: seen 58000 tweets at 1599.3 tps, cost = 0.199
# [batch 59]: seen 60000 tweets at 1600.6 tps, cost = 0.197
# [batch 61]: seen 62000 tweets at 1602.2 tps, cost = 0.196
# [batch 63]: seen 64000 tweets at 1602.5 tps, cost = 0.195
# [batch 65]: seen 66000 tweets at 1603.7 tps, cost = 0.194
# [batch 67]: seen 68000 tweets at 1605.6 tps, cost = 0.193
# [batch 69]: seen 70000 tweets at 1606.9 tps, cost = 0.192
# [batch 71]: seen 72000 tweets at 1608.6 tps, cost = 0.191
# [batch 73]: seen 74000 tweets at 1609.5 tps, cost = 0.190
# [batch 75]: seen 76000 tweets at 1611.0 tps, cost = 0.189
# [batch 77]: seen 78000 tweets at 1612.1 tps, cost = 0.189
# [batch 79]: seen 80000 tweets at 1613.9 tps, cost = 0.188
# [batch 81]: seen 82000 tweets at 1612.8 tps, cost = 0.188
# [batch 83]: seen 84000 tweets at 1612.0 tps, cost = 0.187
# [batch 85]: seen 86000 tweets at 1611.8 tps, cost = 0.186
# [batch 87]: seen 88000 tweets at 1611.5 tps, cost = 0.185
# [batch 89]: seen 90000 tweets at 1612.9 tps, cost = 0.185
# [batch 91]: seen 92000 tweets at 1614.1 tps, cost = 0.184
# [batch 93]: seen 94000 tweets at 1615.2 tps, cost = 0.183
# [batch 95]: seen 96000 tweets at 1616.1 tps, cost = 0.183
# [batch 97]: seen 98000 tweets at 1617.4 tps, cost = 0.182
# [batch 99]: seen 100000 tweets at 1618.6 tps, cost = 0.182
# [batch 101]: seen 102000 tweets at 1619.6 tps, cost = 0.181
# [batch 103]: seen 104000 tweets at 1620.8 tps, cost = 0.180
# [batch 105]: seen 106000 tweets at 1621.9 tps, cost = 0.180
# [batch 107]: seen 108000 tweets at 1622.3 tps, cost = 0.179
# [batch 109]: seen 110000 tweets at 1622.7 tps, cost = 0.179
# [batch 111]: seen 112000 tweets at 1623.0 tps, cost = 0.178
# [batch 113]: seen 114000 tweets at 1623.3 tps, cost = 0.178
# [batch 115]: seen 116000 tweets at 1624.1 tps, cost = 0.177
# [batch 117]: seen 118000 tweets at 1624.9 tps, cost = 0.177
# [batch 119]: seen 120000 tweets at 1625.2 tps, cost = 0.177
# [batch 121]: seen 122000 tweets at 1625.5 tps, cost = 0.176
# [batch 123]: seen 124000 tweets at 1625.5 tps, cost = 0.176
# [batch 125]: seen 126000 tweets at 1625.7 tps, cost = 0.176
# [batch 127]: seen 128000 tweets at 1626.0 tps, cost = 0.175
# [batch 129]: seen 130000 tweets at 1626.1 tps, cost = 0.175
# [batch 131]: seen 132000 tweets at 1626.4 tps, cost = 0.174
# [batch 133]: seen 134000 tweets at 1627.0 tps, cost = 0.174
# [batch 135]: seen 136000 tweets at 1627.1 tps, cost = 0.174
# [batch 137]: seen 138000 tweets at 1627.0 tps, cost = 0.173
# [batch 139]: seen 140000 tweets at 1627.4 tps, cost = 0.173
# [batch 141]: seen 142000 tweets at 1627.4 tps, cost = 0.173
# [batch 143]: seen 144000 tweets at 1627.7 tps, cost = 0.172
# [batch 145]: seen 146000 tweets at 1628.0 tps, cost = 0.172
# [batch 147]: seen 148000 tweets at 1628.2 tps, cost = 0.172
# [batch 149]: seen 150000 tweets at 1628.3 tps, cost = 0.171
# [batch 151]: seen 152000 tweets at 1628.5 tps, cost = 0.171
# [batch 153]: seen 154000 tweets at 1628.5 tps, cost = 0.171
# [batch 155]: seen 156000 tweets at 1628.7 tps, cost = 0.171
# [batch 157]: seen 158000 tweets at 1629.1 tps, cost = 0.170
# [batch 159]: seen 160000 tweets at 1629.7 tps, cost = 0.170
# [batch 161]: seen 162000 tweets at 1629.8 tps, cost = 0.170
# [batch 163]: seen 164000 tweets at 1630.4 tps, cost = 0.169
# [batch 165]: seen 166000 tweets at 1630.7 tps, cost = 0.169
# [batch 167]: seen 168000 tweets at 1631.2 tps, cost = 0.169
# [batch 169]: seen 170000 tweets at 1631.7 tps, cost = 0.169
# [batch 171]: seen 172000 tweets at 1631.8 tps, cost = 0.169
# [batch 173]: seen 174000 tweets at 1632.3 tps, cost = 0.168
# [batch 175]: seen 176000 tweets at 1632.8 tps, cost = 0.168
# [batch 177]: seen 178000 tweets at 1633.5 tps, cost = 0.168
# [batch 179]: seen 180000 tweets at 1634.0 tps, cost = 0.168
# [batch 181]: seen 182000 tweets at 1633.9 tps, cost = 0.167
# [batch 183]: seen 184000 tweets at 1634.1 tps, cost = 0.167
# [batch 185]: seen 186000 tweets at 1634.6 tps, cost = 0.167
# [batch 187]: seen 188000 tweets at 1635.0 tps, cost = 0.167
# [batch 189]: seen 190000 tweets at 1635.5 tps, cost = 0.167
# [batch 191]: seen 192000 tweets at 1635.8 tps, cost = 0.166
# [batch 193]: seen 194000 tweets at 1636.1 tps, cost = 0.166
# [batch 195]: seen 196000 tweets at 1636.5 tps, cost = 0.166
# [batch 197]: seen 198000 tweets at 1636.9 tps, cost = 0.166
# [batch 199]: seen 200000 tweets at 1637.2 tps, cost = 0.165
# [batch 201]: seen 202000 tweets at 1637.4 tps, cost = 0.165
# [batch 203]: seen 204000 tweets at 1637.8 tps, cost = 0.165
# [batch 205]: seen 206000 tweets at 1637.9 tps, cost = 0.165
# [batch 207]: seen 208000 tweets at 1637.6 tps, cost = 0.165
# [batch 209]: seen 210000 tweets at 1637.4 tps, cost = 0.165
# [batch 211]: seen 212000 tweets at 1637.1 tps, cost = 0.164
# [batch 213]: seen 214000 tweets at 1637.2 tps, cost = 0.164
# [batch 215]: seen 216000 tweets at 1637.2 tps, cost = 0.164
# [batch 217]: seen 218000 tweets at 1637.4 tps, cost = 0.164
# [batch 219]: seen 220000 tweets at 1637.5 tps, cost = 0.164
# [batch 221]: seen 222000 tweets at 1637.6 tps, cost = 0.163
# [batch 223]: seen 224000 tweets at 1637.7 tps, cost = 0.163
# [batch 225]: seen 226000 tweets at 1637.7 tps, cost = 0.163
# [batch 227]: seen 228000 tweets at 1637.7 tps, cost = 0.163
# [batch 229]: seen 230000 tweets at 1637.5 tps, cost = 0.163
# [batch 231]: seen 232000 tweets at 1637.6 tps, cost = 0.163
# [batch 233]: seen 234000 tweets at 1637.7 tps, cost = 0.162
# [batch 235]: seen 236000 tweets at 1637.6 tps, cost = 0.162
# [batch 237]: seen 238000 tweets at 1637.6 tps, cost = 0.162
# [batch 239]: seen 240000 tweets at 1637.7 tps, cost = 0.162
# [batch 241]: seen 242000 tweets at 1637.5 tps, cost = 0.162
# [batch 243]: seen 244000 tweets at 1637.3 tps, cost = 0.162
# [batch 245]: seen 246000 tweets at 1637.3 tps, cost = 0.161
# [batch 247]: seen 248000 tweets at 1637.6 tps, cost = 0.161
# [batch 249]: seen 250000 tweets at 1637.7 tps, cost = 0.161
# [batch 251]: seen 252000 tweets at 1637.9 tps, cost = 0.161
# [batch 253]: seen 254000 tweets at 1638.0 tps, cost = 0.161
# [batch 255]: seen 256000 tweets at 1638.1 tps, cost = 0.161
# [batch 257]: seen 258000 tweets at 1638.3 tps, cost = 0.161
# [batch 259]: seen 260000 tweets at 1638.7 tps, cost = 0.160
# [batch 261]: seen 262000 tweets at 1639.0 tps, cost = 0.160
# [batch 263]: seen 264000 tweets at 1639.1 tps, cost = 0.160
# [batch 265]: seen 266000 tweets at 1639.5 tps, cost = 0.160
# [batch 267]: seen 268000 tweets at 1639.8 tps, cost = 0.160
# [batch 269]: seen 270000 tweets at 1639.9 tps, cost = 0.160
# [batch 271]: seen 272000 tweets at 1640.1 tps, cost = 0.160
# [batch 273]: seen 274000 tweets at 1640.2 tps, cost = 0.160
# [batch 275]: seen 276000 tweets at 1640.2 tps, cost = 0.159
# [batch 277]: seen 278000 tweets at 1640.3 tps, cost = 0.159
# [batch 279]: seen 280000 tweets at 1640.7 tps, cost = 0.159
# [batch 281]: seen 282000 tweets at 1640.7 tps, cost = 0.159
# [batch 283]: seen 284000 tweets at 1640.9 tps, cost = 0.159
# [batch 285]: seen 286000 tweets at 1641.2 tps, cost = 0.159
# [batch 287]: seen 288000 tweets at 1641.5 tps, cost = 0.159
# [batch 289]: seen 290000 tweets at 1641.8 tps, cost = 0.159
# [batch 291]: seen 292000 tweets at 1641.9 tps, cost = 0.159
# [batch 293]: seen 294000 tweets at 1642.0 tps, cost = 0.158
# [batch 295]: seen 296000 tweets at 1642.2 tps, cost = 0.158
# [batch 297]: seen 298000 tweets at 1642.4 tps, cost = 0.158
# [batch 299]: seen 300000 tweets at 1642.8 tps, cost = 0.158
# [batch 301]: seen 302000 tweets at 1642.9 tps, cost = 0.158
# [batch 303]: seen 304000 tweets at 1643.0 tps, cost = 0.158
# [batch 305]: seen 306000 tweets at 1643.1 tps, cost = 0.158
# [batch 307]: seen 308000 tweets at 1643.1 tps, cost = 0.158
# [batch 309]: seen 310000 tweets at 1643.1 tps, cost = 0.157
# [batch 311]: seen 312000 tweets at 1643.1 tps, cost = 0.157
# [batch 313]: seen 314000 tweets at 1643.1 tps, cost = 0.157
# [batch 315]: seen 316000 tweets at 1643.2 tps, cost = 0.157
# [batch 317]: seen 318000 tweets at 1643.3 tps, cost = 0.157
# [batch 319]: seen 320000 tweets at 1643.4 tps, cost = 0.157
# [batch 321]: seen 322000 tweets at 1643.3 tps, cost = 0.157
# [batch 323]: seen 324000 tweets at 1643.3 tps, cost = 0.157
# [batch 325]: seen 326000 tweets at 1643.3 tps, cost = 0.157
# [batch 327]: seen 328000 tweets at 1643.3 tps, cost = 0.157
# [batch 329]: seen 330000 tweets at 1643.4 tps, cost = 0.156
# [batch 331]: seen 332000 tweets at 1643.4 tps, cost = 0.156
# [batch 333]: seen 334000 tweets at 1643.5 tps, cost = 0.156
# [batch 335]: seen 336000 tweets at 1643.6 tps, cost = 0.156
# [batch 337]: seen 338000 tweets at 1643.5 tps, cost = 0.156
# [batch 339]: seen 340000 tweets at 1643.4 tps, cost = 0.156
# [batch 341]: seen 342000 tweets at 1643.4 tps, cost = 0.156
# [batch 343]: seen 344000 tweets at 1643.4 tps, cost = 0.156
# [batch 345]: seen 346000 tweets at 1643.5 tps, cost = 0.156
# [batch 347]: seen 348000 tweets at 1643.6 tps, cost = 0.156
# [batch 349]: seen 350000 tweets at 1643.7 tps, cost = 0.156
# [batch 351]: seen 352000 tweets at 1643.8 tps, cost = 0.155
# [batch 353]: seen 354000 tweets at 1643.8 tps, cost = 0.155
# [batch 355]: seen 356000 tweets at 1643.9 tps, cost = 0.155
# [batch 357]: seen 358000 tweets at 1643.9 tps, cost = 0.155
# [batch 359]: seen 360000 tweets at 1643.7 tps, cost = 0.155
# [batch 361]: seen 362000 tweets at 1643.6 tps, cost = 0.155
# [batch 363]: seen 364000 tweets at 1643.7 tps, cost = 0.155
# [batch 365]: seen 366000 tweets at 1643.7 tps, cost = 0.155
# [batch 367]: seen 368000 tweets at 1644.0 tps, cost = 0.155
# [batch 369]: seen 370000 tweets at 1644.2 tps, cost = 0.155
# [batch 371]: seen 372000 tweets at 1644.3 tps, cost = 0.155
# [batch 373]: seen 374000 tweets at 1644.3 tps, cost = 0.155
# [batch 375]: seen 376000 tweets at 1644.5 tps, cost = 0.155
# [batch 377]: seen 378000 tweets at 1644.8 tps, cost = 0.155
# [batch 379]: seen 380000 tweets at 1645.0 tps, cost = 0.154
# [batch 381]: seen 382000 tweets at 1645.1 tps, cost = 0.154
# [batch 383]: seen 384000 tweets at 1645.2 tps, cost = 0.154
# [batch 385]: seen 386000 tweets at 1645.4 tps, cost = 0.154
# [batch 387]: seen 388000 tweets at 1645.6 tps, cost = 0.154
# [batch 389]: seen 390000 tweets at 1645.8 tps, cost = 0.154
# [batch 391]: seen 392000 tweets at 1645.9 tps, cost = 0.154
# [batch 393]: seen 394000 tweets at 1645.7 tps, cost = 0.154
# [batch 395]: seen 396000 tweets at 1645.9 tps, cost = 0.154
# [batch 397]: seen 398000 tweets at 1645.9 tps, cost = 0.154
# [batch 399]: seen 400000 tweets at 1646.0 tps, cost = 0.154
# [batch 401]: seen 402000 tweets at 1646.1 tps, cost = 0.153
# [batch 403]: seen 404000 tweets at 1646.3 tps, cost = 0.153
# [batch 405]: seen 406000 tweets at 1646.5 tps, cost = 0.153
# [batch 407]: seen 408000 tweets at 1646.6 tps, cost = 0.153
# [batch 409]: seen 410000 tweets at 1646.5 tps, cost = 0.153
# [batch 411]: seen 412000 tweets at 1646.5 tps, cost = 0.153
# [batch 413]: seen 414000 tweets at 1646.6 tps, cost = 0.153
# [batch 415]: seen 416000 tweets at 1646.6 tps, cost = 0.153
# [batch 417]: seen 418000 tweets at 1646.5 tps, cost = 0.153
# [batch 419]: seen 420000 tweets at 1646.5 tps, cost = 0.153
# [batch 421]: seen 422000 tweets at 1646.5 tps, cost = 0.153
# [batch 423]: seen 424000 tweets at 1646.3 tps, cost = 0.153
# [batch 425]: seen 426000 tweets at 1646.3 tps, cost = 0.153
# [batch 427]: seen 428000 tweets at 1646.2 tps, cost = 0.152
# [batch 429]: seen 430000 tweets at 1646.1 tps, cost = 0.152
# [batch 431]: seen 432000 tweets at 1646.1 tps, cost = 0.152
# [batch 433]: seen 434000 tweets at 1646.1 tps, cost = 0.152
# [batch 435]: seen 436000 tweets at 1646.2 tps, cost = 0.152
# [batch 437]: seen 438000 tweets at 1646.2 tps, cost = 0.152
# [batch 439]: seen 440000 tweets at 1645.9 tps, cost = 0.152
# [batch 441]: seen 442000 tweets at 1645.9 tps, cost = 0.152
# [batch 443]: seen 444000 tweets at 1645.9 tps, cost = 0.152
# [batch 445]: seen 446000 tweets at 1646.1 tps, cost = 0.152
# [batch 447]: seen 448000 tweets at 1646.0 tps, cost = 0.152
# [batch 449]: seen 450000 tweets at 1646.0 tps, cost = 0.152
# [batch 451]: seen 452000 tweets at 1646.1 tps, cost = 0.152
# [batch 453]: seen 454000 tweets at 1645.8 tps, cost = 0.152
# [batch 455]: seen 456000 tweets at 1645.7 tps, cost = 0.152
# [batch 457]: seen 458000 tweets at 1645.8 tps, cost = 0.152
# [batch 459]: seen 460000 tweets at 1645.9 tps, cost = 0.151
# [batch 461]: seen 462000 tweets at 1645.9 tps, cost = 0.151
# [batch 463]: seen 464000 tweets at 1645.9 tps, cost = 0.151
# [batch 465]: seen 466000 tweets at 1646.0 tps, cost = 0.151
# [batch 467]: seen 468000 tweets at 1646.1 tps, cost = 0.151
# [batch 469]: seen 470000 tweets at 1646.3 tps, cost = 0.151
# [batch 471]: seen 472000 tweets at 1646.5 tps, cost = 0.151
# [batch 473]: seen 474000 tweets at 1646.5 tps, cost = 0.151
# [batch 475]: seen 476000 tweets at 1646.5 tps, cost = 0.151
# [batch 477]: seen 478000 tweets at 1646.7 tps, cost = 0.151
# [batch 479]: seen 480000 tweets at 1646.8 tps, cost = 0.151
# [batch 481]: seen 482000 tweets at 1647.0 tps, cost = 0.151
# [batch 483]: seen 484000 tweets at 1647.1 tps, cost = 0.151
# [batch 485]: seen 486000 tweets at 1647.3 tps, cost = 0.151
# [batch 487]: seen 488000 tweets at 1647.4 tps, cost = 0.151
# [batch 489]: seen 490000 tweets at 1647.5 tps, cost = 0.151
# [batch 491]: seen 492000 tweets at 1647.7 tps, cost = 0.150
# [batch 493]: seen 494000 tweets at 1647.9 tps, cost = 0.150
# [batch 495]: seen 496000 tweets at 1648.0 tps, cost = 0.150
# [batch 497]: seen 498000 tweets at 1648.2 tps, cost = 0.150
# [batch 499]: seen 500000 tweets at 1648.2 tps, cost = 0.150
# [batch 501]: seen 502000 tweets at 1648.1 tps, cost = 0.150
# [batch 503]: seen 504000 tweets at 1648.1 tps, cost = 0.150
# [batch 505]: seen 506000 tweets at 1648.0 tps, cost = 0.150
# [batch 507]: seen 508000 tweets at 1648.0 tps, cost = 0.150
# [batch 509]: seen 510000 tweets at 1648.0 tps, cost = 0.150
# [batch 511]: seen 512000 tweets at 1648.0 tps, cost = 0.150
# [batch 513]: seen 514000 tweets at 1648.0 tps, cost = 0.150
# [batch 515]: seen 516000 tweets at 1647.9 tps, cost = 0.150
# [batch 517]: seen 518000 tweets at 1648.0 tps, cost = 0.150
# [batch 519]: seen 520000 tweets at 1648.0 tps, cost = 0.150
# [batch 521]: seen 522000 tweets at 1647.9 tps, cost = 0.150
# [batch 523]: seen 524000 tweets at 1647.8 tps, cost = 0.150
# [batch 525]: seen 526000 tweets at 1647.9 tps, cost = 0.150
# [batch 527]: seen 528000 tweets at 1647.9 tps, cost = 0.149
# [batch 529]: seen 530000 tweets at 1647.9 tps, cost = 0.149
# [batch 531]: seen 532000 tweets at 1647.8 tps, cost = 0.149
# [batch 533]: seen 534000 tweets at 1647.9 tps, cost = 0.149
# [batch 535]: seen 536000 tweets at 1647.9 tps, cost = 0.149
# [batch 537]: seen 538000 tweets at 1648.1 tps, cost = 0.149
# [batch 539]: seen 540000 tweets at 1648.1 tps, cost = 0.149
# [batch 541]: seen 542000 tweets at 1647.9 tps, cost = 0.149
# [batch 543]: seen 544000 tweets at 1647.4 tps, cost = 0.149
# [batch 545]: seen 546000 tweets at 1646.9 tps, cost = 0.149
# [batch 547]: seen 548000 tweets at 1646.4 tps, cost = 0.149
# [batch 549]: seen 550000 tweets at 1645.7 tps, cost = 0.149
# [batch 551]: seen 552000 tweets at 1645.1 tps, cost = 0.149
# [batch 553]: seen 554000 tweets at 1644.4 tps, cost = 0.149
# [batch 555]: seen 556000 tweets at 1643.9 tps, cost = 0.149
# [batch 557]: seen 558000 tweets at 1643.7 tps, cost = 0.149
# [batch 559]: seen 560000 tweets at 1643.6 tps, cost = 0.149
# [batch 561]: seen 562000 tweets at 1643.6 tps, cost = 0.149
# [batch 563]: seen 564000 tweets at 1643.6 tps, cost = 0.149
# [batch 565]: seen 566000 tweets at 1643.7 tps, cost = 0.149
# [batch 567]: seen 568000 tweets at 1643.8 tps, cost = 0.149
# [batch 569]: seen 570000 tweets at 1643.9 tps, cost = 0.148
# [batch 571]: seen 572000 tweets at 1644.0 tps, cost = 0.148
# [batch 573]: seen 574000 tweets at 1644.2 tps, cost = 0.148
# [batch 575]: seen 576000 tweets at 1644.2 tps, cost = 0.148
# [batch 577]: seen 578000 tweets at 1644.3 tps, cost = 0.148
# [batch 579]: seen 580000 tweets at 1644.4 tps, cost = 0.148
# [batch 581]: seen 582000 tweets at 1644.4 tps, cost = 0.148
# [batch 583]: seen 584000 tweets at 1644.3 tps, cost = 0.148
# [batch 585]: seen 586000 tweets at 1644.2 tps, cost = 0.148
# [batch 587]: seen 588000 tweets at 1644.0 tps, cost = 0.148
# [batch 589]: seen 590000 tweets at 1643.7 tps, cost = 0.148
# [batch 591]: seen 592000 tweets at 1643.6 tps, cost = 0.148
# [batch 593]: seen 594000 tweets at 1643.6 tps, cost = 0.148
# [batch 595]: seen 596000 tweets at 1643.8 tps, cost = 0.148
# [batch 597]: seen 598000 tweets at 1643.8 tps, cost = 0.148
# [batch 599]: seen 600000 tweets at 1643.8 tps, cost = 0.148
# [batch 601]: seen 602000 tweets at 1643.9 tps, cost = 0.148
# [batch 603]: seen 604000 tweets at 1643.9 tps, cost = 0.148
# [batch 605]: seen 606000 tweets at 1643.9 tps, cost = 0.148
# [batch 607]: seen 608000 tweets at 1643.9 tps, cost = 0.148
# [batch 609]: seen 610000 tweets at 1644.0 tps, cost = 0.148
# [batch 611]: seen 612000 tweets at 1644.0 tps, cost = 0.147
# [batch 613]: seen 614000 tweets at 1643.9 tps, cost = 0.147
# [batch 615]: seen 616000 tweets at 1643.9 tps, cost = 0.147
# [batch 617]: seen 618000 tweets at 1643.9 tps, cost = 0.147
# [batch 619]: seen 620000 tweets at 1643.9 tps, cost = 0.147
# [batch 621]: seen 622000 tweets at 1643.9 tps, cost = 0.147
# [batch 623]: seen 624000 tweets at 1643.9 tps, cost = 0.147
# [batch 625]: seen 626000 tweets at 1643.9 tps, cost = 0.147
# [batch 627]: seen 628000 tweets at 1643.9 tps, cost = 0.147
# [batch 629]: seen 630000 tweets at 1643.9 tps, cost = 0.147
# [batch 631]: seen 632000 tweets at 1643.9 tps, cost = 0.147
# [batch 633]: seen 634000 tweets at 1643.9 tps, cost = 0.147
# [batch 635]: seen 636000 tweets at 1643.9 tps, cost = 0.147
# [batch 637]: seen 638000 tweets at 1644.0 tps, cost = 0.147
# [batch 639]: seen 640000 tweets at 1643.9 tps, cost = 0.147
# [batch 641]: seen 642000 tweets at 1643.9 tps, cost = 0.147
# [batch 643]: seen 644000 tweets at 1643.9 tps, cost = 0.147
# [batch 645]: seen 646000 tweets at 1644.0 tps, cost = 0.147
# [batch 647]: seen 648000 tweets at 1644.0 tps, cost = 0.147
# [batch 649]: seen 650000 tweets at 1644.0 tps, cost = 0.147
# [batch 651]: seen 652000 tweets at 1644.0 tps, cost = 0.147
# [batch 653]: seen 654000 tweets at 1644.0 tps, cost = 0.147
# [batch 655]: seen 656000 tweets at 1644.1 tps, cost = 0.147
# [batch 657]: seen 658000 tweets at 1644.1 tps, cost = 0.147
# [batch 659]: seen 660000 tweets at 1644.2 tps, cost = 0.147
# [batch 661]: seen 662000 tweets at 1644.3 tps, cost = 0.147
# [batch 663]: seen 664000 tweets at 1644.4 tps, cost = 0.146
# [batch 665]: seen 666000 tweets at 1644.6 tps, cost = 0.146
# [batch 667]: seen 668000 tweets at 1644.6 tps, cost = 0.146
# [batch 669]: seen 670000 tweets at 1644.6 tps, cost = 0.146
# [batch 671]: seen 672000 tweets at 1644.6 tps, cost = 0.146
# [batch 673]: seen 674000 tweets at 1644.7 tps, cost = 0.146
# [batch 675]: seen 676000 tweets at 1644.8 tps, cost = 0.146
# [batch 677]: seen 678000 tweets at 1644.9 tps, cost = 0.146
# [batch 679]: seen 680000 tweets at 1644.9 tps, cost = 0.146
# [batch 681]: seen 682000 tweets at 1645.0 tps, cost = 0.146
# [batch 683]: seen 684000 tweets at 1645.1 tps, cost = 0.146
# [batch 685]: seen 686000 tweets at 1645.2 tps, cost = 0.146
# [batch 687]: seen 688000 tweets at 1645.3 tps, cost = 0.146
# [batch 689]: seen 690000 tweets at 1645.4 tps, cost = 0.146
# [batch 691]: seen 692000 tweets at 1645.6 tps, cost = 0.146
# [batch 693]: seen 694000 tweets at 1645.7 tps, cost = 0.146
# [batch 695]: seen 696000 tweets at 1645.8 tps, cost = 0.146
# [batch 697]: seen 698000 tweets at 1645.9 tps, cost = 0.146
# [batch 699]: seen 700000 tweets at 1645.9 tps, cost = 0.146
# [batch 701]: seen 702000 tweets at 1645.9 tps, cost = 0.146
# [batch 703]: seen 704000 tweets at 1645.9 tps, cost = 0.146
# [batch 705]: seen 706000 tweets at 1645.9 tps, cost = 0.146
# [batch 707]: seen 708000 tweets at 1646.0 tps, cost = 0.146
# [batch 709]: seen 710000 tweets at 1645.9 tps, cost = 0.146
# [batch 711]: seen 712000 tweets at 1645.9 tps, cost = 0.146
# [batch 713]: seen 714000 tweets at 1646.0 tps, cost = 0.146
# [batch 715]: seen 716000 tweets at 1646.0 tps, cost = 0.146
# [batch 717]: seen 718000 tweets at 1646.0 tps, cost = 0.146
# [batch 719]: seen 720000 tweets at 1646.0 tps, cost = 0.146
# [batch 721]: seen 722000 tweets at 1646.0 tps, cost = 0.146
# [batch 723]: seen 724000 tweets at 1646.1 tps, cost = 0.146
# [batch 725]: seen 726000 tweets at 1646.0 tps, cost = 0.146
# [batch 727]: seen 728000 tweets at 1645.9 tps, cost = 0.145
# [batch 729]: seen 730000 tweets at 1645.9 tps, cost = 0.145
# [batch 731]: seen 732000 tweets at 1645.8 tps, cost = 0.145
# [batch 733]: seen 734000 tweets at 1645.9 tps, cost = 0.145
# [batch 735]: seen 736000 tweets at 1645.8 tps, cost = 0.145
# [batch 737]: seen 738000 tweets at 1645.9 tps, cost = 0.145
# [batch 739]: seen 740000 tweets at 1645.8 tps, cost = 0.145
# [batch 741]: seen 742000 tweets at 1645.9 tps, cost = 0.145
# [batch 743]: seen 744000 tweets at 1646.0 tps, cost = 0.145
# [batch 745]: seen 746000 tweets at 1645.9 tps, cost = 0.145
# [batch 747]: seen 748000 tweets at 1645.9 tps, cost = 0.145
# [batch 749]: seen 750000 tweets at 1645.9 tps, cost = 0.145
# [batch 751]: seen 752000 tweets at 1645.9 tps, cost = 0.145
# [batch 753]: seen 754000 tweets at 1645.9 tps, cost = 0.145
# [batch 755]: seen 756000 tweets at 1645.9 tps, cost = 0.145
# [batch 757]: seen 758000 tweets at 1645.9 tps, cost = 0.145
# [batch 759]: seen 760000 tweets at 1646.0 tps, cost = 0.145
# [batch 761]: seen 762000 tweets at 1646.1 tps, cost = 0.145
# [batch 763]: seen 764000 tweets at 1646.2 tps, cost = 0.145
# [batch 765]: seen 766000 tweets at 1646.3 tps, cost = 0.145
# [batch 767]: seen 768000 tweets at 1646.4 tps, cost = 0.145
# [batch 769]: seen 770000 tweets at 1646.5 tps, cost = 0.145
# [batch 771]: seen 772000 tweets at 1646.6 tps, cost = 0.145
# [batch 773]: seen 774000 tweets at 1646.7 tps, cost = 0.145
# [batch 775]: seen 776000 tweets at 1646.7 tps, cost = 0.145
# [batch 777]: seen 778000 tweets at 1646.8 tps, cost = 0.145
# [batch 779]: seen 780000 tweets at 1646.8 tps, cost = 0.145
# [batch 781]: seen 782000 tweets at 1646.9 tps, cost = 0.145
# [batch 783]: seen 784000 tweets at 1646.9 tps, cost = 0.145
# [batch 785]: seen 786000 tweets at 1647.0 tps, cost = 0.145
# [batch 787]: seen 788000 tweets at 1647.1 tps, cost = 0.145
# [batch 789]: seen 790000 tweets at 1647.2 tps, cost = 0.145
# [batch 791]: seen 792000 tweets at 1647.3 tps, cost = 0.145
# [batch 793]: seen 794000 tweets at 1647.4 tps, cost = 0.144
# [batch 795]: seen 796000 tweets at 1647.5 tps, cost = 0.144
# [batch 797]: seen 798000 tweets at 1647.5 tps, cost = 0.144
# [batch 799]: seen 800000 tweets at 1647.4 tps, cost = 0.144
# [batch 801]: seen 802000 tweets at 1647.5 tps, cost = 0.144
# [batch 803]: seen 804000 tweets at 1647.5 tps, cost = 0.144
# [batch 805]: seen 806000 tweets at 1647.6 tps, cost = 0.144
# [batch 807]: seen 808000 tweets at 1647.6 tps, cost = 0.144
# [batch 809]: seen 810000 tweets at 1647.6 tps, cost = 0.144
# [batch 811]: seen 812000 tweets at 1647.7 tps, cost = 0.144
# [batch 813]: seen 814000 tweets at 1647.7 tps, cost = 0.144
# [batch 815]: seen 816000 tweets at 1647.7 tps, cost = 0.144
# [batch 817]: seen 818000 tweets at 1647.7 tps, cost = 0.144
# [batch 819]: seen 820000 tweets at 1647.7 tps, cost = 0.144
# [batch 821]: seen 822000 tweets at 1647.7 tps, cost = 0.144
# [batch 823]: seen 824000 tweets at 1647.7 tps, cost = 0.144
# [batch 825]: seen 826000 tweets at 1647.7 tps, cost = 0.144
# [batch 827]: seen 828000 tweets at 1647.7 tps, cost = 0.144
# [batch 829]: seen 830000 tweets at 1647.6 tps, cost = 0.144
# [batch 831]: seen 832000 tweets at 1647.6 tps, cost = 0.144
# [batch 833]: seen 834000 tweets at 1647.6 tps, cost = 0.144
# [batch 835]: seen 836000 tweets at 1647.5 tps, cost = 0.144
# [batch 837]: seen 838000 tweets at 1647.6 tps, cost = 0.144
# [batch 839]: seen 840000 tweets at 1647.6 tps, cost = 0.144
# [batch 841]: seen 842000 tweets at 1647.7 tps, cost = 0.144
# [batch 843]: seen 844000 tweets at 1647.7 tps, cost = 0.144
# [batch 845]: seen 846000 tweets at 1647.7 tps, cost = 0.144
# [batch 847]: seen 848000 tweets at 1647.7 tps, cost = 0.144
# [batch 849]: seen 850000 tweets at 1647.7 tps, cost = 0.144
# [batch 851]: seen 852000 tweets at 1647.6 tps, cost = 0.144
# [batch 853]: seen 854000 tweets at 1647.6 tps, cost = 0.144
# [batch 855]: seen 856000 tweets at 1647.6 tps, cost = 0.144
# [batch 857]: seen 858000 tweets at 1647.6 tps, cost = 0.144
# [batch 859]: seen 860000 tweets at 1647.7 tps, cost = 0.144
# [batch 861]: seen 862000 tweets at 1647.8 tps, cost = 0.144
# [batch 863]: seen 864000 tweets at 1647.9 tps, cost = 0.143
# [batch 865]: seen 866000 tweets at 1648.0 tps, cost = 0.143
# [batch 867]: seen 868000 tweets at 1648.0 tps, cost = 0.143
# [batch 869]: seen 870000 tweets at 1648.0 tps, cost = 0.143
# [batch 871]: seen 872000 tweets at 1648.1 tps, cost = 0.143
# [batch 873]: seen 874000 tweets at 1648.0 tps, cost = 0.143
# [batch 875]: seen 876000 tweets at 1648.1 tps, cost = 0.143
# [batch 877]: seen 878000 tweets at 1648.1 tps, cost = 0.143
# [batch 879]: seen 880000 tweets at 1648.2 tps, cost = 0.143
# [batch 881]: seen 882000 tweets at 1648.3 tps, cost = 0.143
# [batch 883]: seen 884000 tweets at 1648.3 tps, cost = 0.143
# [batch 885]: seen 886000 tweets at 1648.4 tps, cost = 0.143
# [batch 887]: seen 888000 tweets at 1648.5 tps, cost = 0.143
# [batch 889]: seen 890000 tweets at 1648.5 tps, cost = 0.143
# [batch 891]: seen 892000 tweets at 1648.6 tps, cost = 0.143
# [batch 893]: seen 894000 tweets at 1648.6 tps, cost = 0.143
# [batch 895]: seen 896000 tweets at 1648.6 tps, cost = 0.143
# [batch 897]: seen 898000 tweets at 1648.7 tps, cost = 0.143
# [batch 899]: seen 900000 tweets at 1648.7 tps, cost = 0.143
# [batch 901]: seen 902000 tweets at 1648.8 tps, cost = 0.143
# [batch 903]: seen 904000 tweets at 1648.8 tps, cost = 0.143
# [batch 905]: seen 906000 tweets at 1648.8 tps, cost = 0.143
# [batch 907]: seen 908000 tweets at 1648.8 tps, cost = 0.143
# [batch 909]: seen 910000 tweets at 1648.8 tps, cost = 0.143
# [batch 911]: seen 912000 tweets at 1648.9 tps, cost = 0.143
# [batch 913]: seen 914000 tweets at 1648.9 tps, cost = 0.143
# [batch 915]: seen 916000 tweets at 1648.9 tps, cost = 0.143
# [batch 917]: seen 918000 tweets at 1648.8 tps, cost = 0.143
# [batch 919]: seen 920000 tweets at 1648.8 tps, cost = 0.143
# [batch 921]: seen 922000 tweets at 1648.8 tps, cost = 0.143
# [batch 923]: seen 924000 tweets at 1648.8 tps, cost = 0.143
# [batch 925]: seen 926000 tweets at 1648.8 tps, cost = 0.143
# [batch 927]: seen 928000 tweets at 1648.8 tps, cost = 0.143
# [batch 929]: seen 930000 tweets at 1648.8 tps, cost = 0.143
# [batch 931]: seen 932000 tweets at 1648.9 tps, cost = 0.143
# [batch 933]: seen 934000 tweets at 1648.8 tps, cost = 0.143
# [batch 935]: seen 936000 tweets at 1648.8 tps, cost = 0.143
# [batch 937]: seen 938000 tweets at 1648.8 tps, cost = 0.143
# [batch 939]: seen 940000 tweets at 1648.7 tps, cost = 0.143
# [batch 941]: seen 942000 tweets at 1648.8 tps, cost = 0.143
# [batch 943]: seen 944000 tweets at 1648.8 tps, cost = 0.142
# [batch 945]: seen 946000 tweets at 1648.8 tps, cost = 0.142
# [batch 947]: seen 948000 tweets at 1648.8 tps, cost = 0.142
# [batch 949]: seen 950000 tweets at 1648.8 tps, cost = 0.142
# [batch 951]: seen 952000 tweets at 1648.8 tps, cost = 0.142
# [batch 953]: seen 954000 tweets at 1648.7 tps, cost = 0.142
# [batch 955]: seen 956000 tweets at 1648.7 tps, cost = 0.142
# [batch 957]: seen 958000 tweets at 1648.8 tps, cost = 0.142
# [batch 959]: seen 960000 tweets at 1648.9 tps, cost = 0.142
# [batch 961]: seen 962000 tweets at 1649.0 tps, cost = 0.142
# [batch 963]: seen 964000 tweets at 1649.1 tps, cost = 0.142
# [batch 965]: seen 966000 tweets at 1649.2 tps, cost = 0.142
# [batch 967]: seen 968000 tweets at 1649.3 tps, cost = 0.142
# [batch 969]: seen 970000 tweets at 1649.3 tps, cost = 0.142
# [batch 971]: seen 972000 tweets at 1649.4 tps, cost = 0.142
# [batch 973]: seen 974000 tweets at 1649.4 tps, cost = 0.142
# [batch 975]: seen 976000 tweets at 1649.5 tps, cost = 0.142
# [batch 977]: seen 978000 tweets at 1649.6 tps, cost = 0.142
# [batch 979]: seen 980000 tweets at 1649.6 tps, cost = 0.142
# [batch 981]: seen 982000 tweets at 1649.7 tps, cost = 0.142
# [batch 983]: seen 984000 tweets at 1649.8 tps, cost = 0.142
# [batch 985]: seen 986000 tweets at 1649.9 tps, cost = 0.142
# [batch 987]: seen 988000 tweets at 1650.0 tps, cost = 0.142
# [batch 989]: seen 990000 tweets at 1650.1 tps, cost = 0.142
# [batch 991]: seen 992000 tweets at 1650.2 tps, cost = 0.142
# [batch 993]: seen 994000 tweets at 1650.2 tps, cost = 0.142
# [batch 995]: seen 996000 tweets at 1650.3 tps, cost = 0.142
# [batch 997]: seen 998000 tweets at 1650.4 tps, cost = 0.142
# [batch 999]: seen 1000000 tweets at 1650.4 tps, cost = 0.142
# [batch 1001]: seen 1002000 tweets at 1650.4 tps, cost = 0.142
# [batch 1003]: seen 1004000 tweets at 1650.5 tps, cost = 0.142
# [batch 1005]: seen 1006000 tweets at 1650.4 tps, cost = 0.142
# [batch 1007]: seen 1008000 tweets at 1650.4 tps, cost = 0.142
# [batch 1009]: seen 1010000 tweets at 1650.5 tps, cost = 0.142
# [batch 1011]: seen 1012000 tweets at 1650.4 tps, cost = 0.142
# [batch 1013]: seen 1014000 tweets at 1650.5 tps, cost = 0.142
# [batch 1015]: seen 1016000 tweets at 1650.5 tps, cost = 0.142
# [batch 1017]: seen 1018000 tweets at 1650.5 tps, cost = 0.142
# [batch 1019]: seen 1020000 tweets at 1650.5 tps, cost = 0.142
# [batch 1021]: seen 1022000 tweets at 1650.6 tps, cost = 0.142
# [batch 1023]: seen 1024000 tweets at 1650.6 tps, cost = 0.142
# [batch 1025]: seen 1026000 tweets at 1650.6 tps, cost = 0.142
# [batch 1027]: seen 1028000 tweets at 1650.6 tps, cost = 0.142
# [batch 1029]: seen 1030000 tweets at 1650.6 tps, cost = 0.142
# [batch 1031]: seen 1032000 tweets at 1650.6 tps, cost = 0.142
# [batch 1033]: seen 1034000 tweets at 1650.5 tps, cost = 0.142
# [batch 1035]: seen 1036000 tweets at 1650.6 tps, cost = 0.142
# [batch 1037]: seen 1038000 tweets at 1650.6 tps, cost = 0.142
# [batch 1039]: seen 1040000 tweets at 1650.6 tps, cost = 0.142
# [batch 1041]: seen 1042000 tweets at 1650.6 tps, cost = 0.141
# [batch 1043]: seen 1044000 tweets at 1650.6 tps, cost = 0.141
# [batch 1045]: seen 1046000 tweets at 1650.5 tps, cost = 0.141
# [batch 1047]: seen 1048000 tweets at 1650.6 tps, cost = 0.141
# [batch 1049]: seen 1050000 tweets at 1650.6 tps, cost = 0.141
# [batch 1051]: seen 1052000 tweets at 1650.6 tps, cost = 0.141
# [batch 1053]: seen 1054000 tweets at 1650.6 tps, cost = 0.141
# [batch 1055]: seen 1056000 tweets at 1650.6 tps, cost = 0.141
# [batch 1057]: seen 1058000 tweets at 1650.4 tps, cost = 0.141
# [batch 1059]: seen 1060000 tweets at 1650.2 tps, cost = 0.141
# [batch 1061]: seen 1062000 tweets at 1650.1 tps, cost = 0.141
# [batch 1063]: seen 1064000 tweets at 1649.9 tps, cost = 0.141
# [batch 1065]: seen 1066000 tweets at 1649.7 tps, cost = 0.141
# [batch 1067]: seen 1068000 tweets at 1649.5 tps, cost = 0.141
# [batch 1069]: seen 1070000 tweets at 1649.3 tps, cost = 0.141
# [batch 1071]: seen 1072000 tweets at 1649.2 tps, cost = 0.141
# [batch 1073]: seen 1074000 tweets at 1649.2 tps, cost = 0.141
# [batch 1075]: seen 1076000 tweets at 1649.2 tps, cost = 0.141
# [batch 1077]: seen 1078000 tweets at 1649.2 tps, cost = 0.141
# [batch 1079]: seen 1080000 tweets at 1649.3 tps, cost = 0.141
# [batch 1081]: seen 1082000 tweets at 1649.3 tps, cost = 0.141
# [batch 1083]: seen 1084000 tweets at 1649.4 tps, cost = 0.141
# [batch 1085]: seen 1086000 tweets at 1649.4 tps, cost = 0.141
# [batch 1087]: seen 1088000 tweets at 1649.5 tps, cost = 0.141
# [batch 1089]: seen 1090000 tweets at 1649.4 tps, cost = 0.141
# [batch 1091]: seen 1092000 tweets at 1649.4 tps, cost = 0.141
# [batch 1093]: seen 1094000 tweets at 1649.2 tps, cost = 0.141
# [batch 1095]: seen 1096000 tweets at 1649.2 tps, cost = 0.141
# [batch 1097]: seen 1098000 tweets at 1649.1 tps, cost = 0.141
# [batch 1099]: seen 1100000 tweets at 1649.1 tps, cost = 0.141
# [batch 1101]: seen 1102000 tweets at 1649.2 tps, cost = 0.141
# [batch 1103]: seen 1104000 tweets at 1649.2 tps, cost = 0.141
# [batch 1105]: seen 1106000 tweets at 1649.2 tps, cost = 0.141
# [batch 1107]: seen 1108000 tweets at 1649.2 tps, cost = 0.141
# [batch 1109]: seen 1110000 tweets at 1649.3 tps, cost = 0.141
# [batch 1111]: seen 1112000 tweets at 1649.3 tps, cost = 0.141
# [batch 1113]: seen 1114000 tweets at 1649.4 tps, cost = 0.141
# [batch 1115]: seen 1116000 tweets at 1649.4 tps, cost = 0.141
# [batch 1117]: seen 1118000 tweets at 1649.4 tps, cost = 0.141
# [batch 1119]: seen 1120000 tweets at 1649.4 tps, cost = 0.141
# [epoch 1] Completed in 0:11:19
# [batch 1]: seen 2000 tweets at 1647.2 tps, cost = 0.130
# [batch 3]: seen 4000 tweets at 1664.5 tps, cost = 0.131
# [batch 5]: seen 6000 tweets at 1656.5 tps, cost = 0.130
# [batch 7]: seen 8000 tweets at 1656.2 tps, cost = 0.131
# [batch 9]: seen 10000 tweets at 1655.4 tps, cost = 0.130
# [batch 11]: seen 12000 tweets at 1654.3 tps, cost = 0.129
# [batch 13]: seen 14000 tweets at 1650.3 tps, cost = 0.127
# [batch 15]: seen 16000 tweets at 1649.6 tps, cost = 0.128
# [batch 17]: seen 18000 tweets at 1646.0 tps, cost = 0.128
# [batch 19]: seen 20000 tweets at 1644.5 tps, cost = 0.128
# [batch 21]: seen 22000 tweets at 1646.5 tps, cost = 0.129
# [batch 23]: seen 24000 tweets at 1647.8 tps, cost = 0.129
# [batch 25]: seen 26000 tweets at 1649.0 tps, cost = 0.129
# [batch 27]: seen 28000 tweets at 1646.1 tps, cost = 0.129
# [batch 29]: seen 30000 tweets at 1644.5 tps, cost = 0.129
# [batch 31]: seen 32000 tweets at 1644.1 tps, cost = 0.129
# [batch 33]: seen 34000 tweets at 1645.0 tps, cost = 0.129
# [batch 35]: seen 36000 tweets at 1644.4 tps, cost = 0.128
# [batch 37]: seen 38000 tweets at 1646.0 tps, cost = 0.129
# [batch 39]: seen 40000 tweets at 1647.5 tps, cost = 0.128
# [batch 41]: seen 42000 tweets at 1648.7 tps, cost = 0.129
# [batch 43]: seen 44000 tweets at 1649.1 tps, cost = 0.129
# [batch 45]: seen 46000 tweets at 1650.0 tps, cost = 0.129
# [batch 47]: seen 48000 tweets at 1650.9 tps, cost = 0.128
# [batch 49]: seen 50000 tweets at 1650.9 tps, cost = 0.129
# [batch 51]: seen 52000 tweets at 1652.1 tps, cost = 0.129
# [batch 53]: seen 54000 tweets at 1651.8 tps, cost = 0.129
# [batch 55]: seen 56000 tweets at 1652.3 tps, cost = 0.129
# [batch 57]: seen 58000 tweets at 1653.0 tps, cost = 0.129
# [batch 59]: seen 60000 tweets at 1653.5 tps, cost = 0.129
# [batch 61]: seen 62000 tweets at 1655.0 tps, cost = 0.129
# [batch 63]: seen 64000 tweets at 1655.0 tps, cost = 0.129
# [batch 65]: seen 66000 tweets at 1655.5 tps, cost = 0.129
# [batch 67]: seen 68000 tweets at 1655.2 tps, cost = 0.129
# [batch 69]: seen 70000 tweets at 1655.0 tps, cost = 0.129
# [batch 71]: seen 72000 tweets at 1655.5 tps, cost = 0.129
# [batch 73]: seen 74000 tweets at 1655.5 tps, cost = 0.129
# [batch 75]: seen 76000 tweets at 1656.1 tps, cost = 0.129
# [batch 77]: seen 78000 tweets at 1656.0 tps, cost = 0.129
# [batch 79]: seen 80000 tweets at 1655.7 tps, cost = 0.129
# [batch 81]: seen 82000 tweets at 1655.4 tps, cost = 0.130
# [batch 83]: seen 84000 tweets at 1655.5 tps, cost = 0.129
# [batch 85]: seen 86000 tweets at 1655.0 tps, cost = 0.129
# [batch 87]: seen 88000 tweets at 1655.0 tps, cost = 0.129
# [batch 89]: seen 90000 tweets at 1653.9 tps, cost = 0.129
# [batch 91]: seen 92000 tweets at 1653.8 tps, cost = 0.129
# [batch 93]: seen 94000 tweets at 1653.8 tps, cost = 0.129
# [batch 95]: seen 96000 tweets at 1654.0 tps, cost = 0.129
# [batch 97]: seen 98000 tweets at 1653.0 tps, cost = 0.129
# [batch 99]: seen 100000 tweets at 1652.1 tps, cost = 0.129
# [batch 101]: seen 102000 tweets at 1651.0 tps, cost = 0.129
# [batch 103]: seen 104000 tweets at 1650.1 tps, cost = 0.129
# [batch 105]: seen 106000 tweets at 1650.2 tps, cost = 0.129
# [batch 107]: seen 108000 tweets at 1649.9 tps, cost = 0.129
# [batch 109]: seen 110000 tweets at 1649.7 tps, cost = 0.129
# [batch 111]: seen 112000 tweets at 1649.8 tps, cost = 0.129
# [batch 113]: seen 114000 tweets at 1649.6 tps, cost = 0.129
# [batch 115]: seen 116000 tweets at 1649.6 tps, cost = 0.129
# [batch 117]: seen 118000 tweets at 1649.5 tps, cost = 0.129
# [batch 119]: seen 120000 tweets at 1649.2 tps, cost = 0.129
# [batch 121]: seen 122000 tweets at 1648.8 tps, cost = 0.129
# [batch 123]: seen 124000 tweets at 1648.2 tps, cost = 0.129
# [batch 125]: seen 126000 tweets at 1648.0 tps, cost = 0.129
# [batch 127]: seen 128000 tweets at 1648.0 tps, cost = 0.129
# [batch 129]: seen 130000 tweets at 1648.1 tps, cost = 0.129
# [batch 131]: seen 132000 tweets at 1648.5 tps, cost = 0.129
# [batch 133]: seen 134000 tweets at 1648.7 tps, cost = 0.129
# [batch 135]: seen 136000 tweets at 1649.0 tps, cost = 0.129
# [batch 137]: seen 138000 tweets at 1649.6 tps, cost = 0.129
# [batch 139]: seen 140000 tweets at 1650.2 tps, cost = 0.129
# [batch 141]: seen 142000 tweets at 1650.6 tps, cost = 0.129
# [batch 143]: seen 144000 tweets at 1651.3 tps, cost = 0.129
# [batch 145]: seen 146000 tweets at 1651.8 tps, cost = 0.129
# [batch 147]: seen 148000 tweets at 1651.9 tps, cost = 0.129
# [batch 149]: seen 150000 tweets at 1652.0 tps, cost = 0.128
# [batch 151]: seen 152000 tweets at 1652.1 tps, cost = 0.129
# [batch 153]: seen 154000 tweets at 1652.5 tps, cost = 0.128
# [batch 155]: seen 156000 tweets at 1652.8 tps, cost = 0.128
# [batch 157]: seen 158000 tweets at 1652.7 tps, cost = 0.128
# [batch 159]: seen 160000 tweets at 1652.9 tps, cost = 0.128
# [batch 161]: seen 162000 tweets at 1653.3 tps, cost = 0.128
# [batch 163]: seen 164000 tweets at 1653.5 tps, cost = 0.128
# [batch 165]: seen 166000 tweets at 1653.9 tps, cost = 0.128
# [batch 167]: seen 168000 tweets at 1654.3 tps, cost = 0.128
# [batch 169]: seen 170000 tweets at 1654.5 tps, cost = 0.128
# [batch 171]: seen 172000 tweets at 1654.7 tps, cost = 0.128
# [batch 173]: seen 174000 tweets at 1655.1 tps, cost = 0.128
# [batch 175]: seen 176000 tweets at 1654.9 tps, cost = 0.128
# [batch 177]: seen 178000 tweets at 1655.0 tps, cost = 0.128
# [batch 179]: seen 180000 tweets at 1654.9 tps, cost = 0.128
# [batch 181]: seen 182000 tweets at 1654.8 tps, cost = 0.128
# [batch 183]: seen 184000 tweets at 1654.8 tps, cost = 0.128
# [batch 185]: seen 186000 tweets at 1654.8 tps, cost = 0.128
# [batch 187]: seen 188000 tweets at 1654.4 tps, cost = 0.128
# [batch 189]: seen 190000 tweets at 1654.4 tps, cost = 0.128
# [batch 191]: seen 192000 tweets at 1654.1 tps, cost = 0.128
# [batch 193]: seen 194000 tweets at 1654.0 tps, cost = 0.128
# [batch 195]: seen 196000 tweets at 1653.9 tps, cost = 0.128
# [batch 197]: seen 198000 tweets at 1653.8 tps, cost = 0.128
# [batch 199]: seen 200000 tweets at 1653.7 tps, cost = 0.128
# [batch 201]: seen 202000 tweets at 1653.2 tps, cost = 0.128
# [batch 203]: seen 204000 tweets at 1652.8 tps, cost = 0.128
# [batch 205]: seen 206000 tweets at 1652.5 tps, cost = 0.128
# [batch 207]: seen 208000 tweets at 1652.3 tps, cost = 0.128
# [batch 209]: seen 210000 tweets at 1652.3 tps, cost = 0.128
# [batch 211]: seen 212000 tweets at 1652.2 tps, cost = 0.128
# [batch 213]: seen 214000 tweets at 1652.1 tps, cost = 0.128
# [batch 215]: seen 216000 tweets at 1652.1 tps, cost = 0.128
# [batch 217]: seen 218000 tweets at 1651.8 tps, cost = 0.128
# [batch 219]: seen 220000 tweets at 1651.5 tps, cost = 0.128
# [batch 221]: seen 222000 tweets at 1651.2 tps, cost = 0.128
# [batch 223]: seen 224000 tweets at 1651.3 tps, cost = 0.128
# [batch 225]: seen 226000 tweets at 1651.3 tps, cost = 0.128
# [batch 227]: seen 228000 tweets at 1651.2 tps, cost = 0.128
# [batch 229]: seen 230000 tweets at 1651.3 tps, cost = 0.128
# [batch 231]: seen 232000 tweets at 1651.3 tps, cost = 0.128
# [batch 233]: seen 234000 tweets at 1651.2 tps, cost = 0.128
# [batch 235]: seen 236000 tweets at 1651.4 tps, cost = 0.128
# [batch 237]: seen 238000 tweets at 1651.4 tps, cost = 0.128
# [batch 239]: seen 240000 tweets at 1651.4 tps, cost = 0.128
# [batch 241]: seen 242000 tweets at 1651.6 tps, cost = 0.128
# [batch 243]: seen 244000 tweets at 1651.7 tps, cost = 0.128
# [batch 245]: seen 246000 tweets at 1651.7 tps, cost = 0.128
# [batch 247]: seen 248000 tweets at 1651.9 tps, cost = 0.128
# [batch 249]: seen 250000 tweets at 1651.9 tps, cost = 0.128
# [batch 251]: seen 252000 tweets at 1652.0 tps, cost = 0.128
# [batch 253]: seen 254000 tweets at 1652.2 tps, cost = 0.128
# [batch 255]: seen 256000 tweets at 1652.3 tps, cost = 0.128
# [batch 257]: seen 258000 tweets at 1652.0 tps, cost = 0.128
# [batch 259]: seen 260000 tweets at 1652.2 tps, cost = 0.128
# [batch 261]: seen 262000 tweets at 1652.2 tps, cost = 0.128
# [batch 263]: seen 264000 tweets at 1652.4 tps, cost = 0.128
# [batch 265]: seen 266000 tweets at 1652.2 tps, cost = 0.128
# [batch 267]: seen 268000 tweets at 1652.0 tps, cost = 0.128
# [batch 269]: seen 270000 tweets at 1651.9 tps, cost = 0.128
# [batch 271]: seen 272000 tweets at 1651.8 tps, cost = 0.128
# [batch 273]: seen 274000 tweets at 1651.7 tps, cost = 0.128
# [batch 275]: seen 276000 tweets at 1651.4 tps, cost = 0.128
# [batch 277]: seen 278000 tweets at 1650.6 tps, cost = 0.128
# [batch 279]: seen 280000 tweets at 1650.5 tps, cost = 0.128
# [batch 281]: seen 282000 tweets at 1650.5 tps, cost = 0.128
# [batch 283]: seen 284000 tweets at 1650.3 tps, cost = 0.128
# [batch 285]: seen 286000 tweets at 1650.0 tps, cost = 0.128
# [batch 287]: seen 288000 tweets at 1649.9 tps, cost = 0.128
# [batch 289]: seen 290000 tweets at 1649.7 tps, cost = 0.128
# [batch 291]: seen 292000 tweets at 1649.5 tps, cost = 0.128
# [batch 293]: seen 294000 tweets at 1649.4 tps, cost = 0.128
# [batch 295]: seen 296000 tweets at 1649.2 tps, cost = 0.128
# [batch 297]: seen 298000 tweets at 1649.2 tps, cost = 0.128
# [batch 299]: seen 300000 tweets at 1649.0 tps, cost = 0.128
# [batch 301]: seen 302000 tweets at 1648.9 tps, cost = 0.128
# [batch 303]: seen 304000 tweets at 1648.8 tps, cost = 0.128
# [batch 305]: seen 306000 tweets at 1648.6 tps, cost = 0.128
# [batch 307]: seen 308000 tweets at 1648.3 tps, cost = 0.128
# [batch 309]: seen 310000 tweets at 1648.2 tps, cost = 0.128
# [batch 311]: seen 312000 tweets at 1648.1 tps, cost = 0.128
# [batch 313]: seen 314000 tweets at 1647.9 tps, cost = 0.128
# [batch 315]: seen 316000 tweets at 1647.6 tps, cost = 0.128
# [batch 317]: seen 318000 tweets at 1647.4 tps, cost = 0.128
# [batch 319]: seen 320000 tweets at 1647.2 tps, cost = 0.128
# [batch 321]: seen 322000 tweets at 1647.2 tps, cost = 0.128
# [batch 323]: seen 324000 tweets at 1647.2 tps, cost = 0.127
# [batch 325]: seen 326000 tweets at 1647.1 tps, cost = 0.127
# [batch 327]: seen 328000 tweets at 1646.6 tps, cost = 0.127
# [batch 329]: seen 330000 tweets at 1646.4 tps, cost = 0.127
# [batch 331]: seen 332000 tweets at 1646.2 tps, cost = 0.127
# [batch 333]: seen 334000 tweets at 1646.2 tps, cost = 0.127
# [batch 335]: seen 336000 tweets at 1646.3 tps, cost = 0.127
# [batch 337]: seen 338000 tweets at 1646.3 tps, cost = 0.127
# [batch 339]: seen 340000 tweets at 1646.4 tps, cost = 0.127
# [batch 341]: seen 342000 tweets at 1646.6 tps, cost = 0.127
# [batch 343]: seen 344000 tweets at 1646.6 tps, cost = 0.127
# [batch 345]: seen 346000 tweets at 1646.6 tps, cost = 0.127
# [batch 347]: seen 348000 tweets at 1646.9 tps, cost = 0.127
# [batch 349]: seen 350000 tweets at 1647.1 tps, cost = 0.127
# [batch 351]: seen 352000 tweets at 1647.3 tps, cost = 0.127
# [batch 353]: seen 354000 tweets at 1647.5 tps, cost = 0.127
# [batch 355]: seen 356000 tweets at 1647.6 tps, cost = 0.127
# [batch 357]: seen 358000 tweets at 1647.7 tps, cost = 0.127
# [batch 359]: seen 360000 tweets at 1647.9 tps, cost = 0.127
# [batch 361]: seen 362000 tweets at 1648.0 tps, cost = 0.127
# [batch 363]: seen 364000 tweets at 1648.1 tps, cost = 0.127
# [batch 365]: seen 366000 tweets at 1648.0 tps, cost = 0.127
# [batch 367]: seen 368000 tweets at 1648.1 tps, cost = 0.127
# [batch 369]: seen 370000 tweets at 1648.2 tps, cost = 0.127
# [batch 371]: seen 372000 tweets at 1648.3 tps, cost = 0.127
# [batch 373]: seen 374000 tweets at 1648.2 tps, cost = 0.127
# [batch 375]: seen 376000 tweets at 1648.3 tps, cost = 0.127
# [batch 377]: seen 378000 tweets at 1648.2 tps, cost = 0.127
# [batch 379]: seen 380000 tweets at 1648.0 tps, cost = 0.127
# [batch 381]: seen 382000 tweets at 1648.0 tps, cost = 0.127
# [batch 383]: seen 384000 tweets at 1647.9 tps, cost = 0.128
# [batch 385]: seen 386000 tweets at 1647.8 tps, cost = 0.128
# [batch 387]: seen 388000 tweets at 1647.7 tps, cost = 0.127
# [batch 389]: seen 390000 tweets at 1647.7 tps, cost = 0.127
# [batch 391]: seen 392000 tweets at 1647.6 tps, cost = 0.127
# [batch 393]: seen 394000 tweets at 1647.5 tps, cost = 0.127
# [batch 395]: seen 396000 tweets at 1647.5 tps, cost = 0.127
# [batch 397]: seen 398000 tweets at 1647.4 tps, cost = 0.127
# [batch 399]: seen 400000 tweets at 1647.3 tps, cost = 0.127
# [batch 401]: seen 402000 tweets at 1647.1 tps, cost = 0.127
# [batch 403]: seen 404000 tweets at 1647.0 tps, cost = 0.127
# [batch 405]: seen 406000 tweets at 1646.9 tps, cost = 0.127
# [batch 407]: seen 408000 tweets at 1646.9 tps, cost = 0.127
# [batch 409]: seen 410000 tweets at 1646.8 tps, cost = 0.127
# [batch 411]: seen 412000 tweets at 1646.7 tps, cost = 0.127
# [batch 413]: seen 414000 tweets at 1646.7 tps, cost = 0.127
# [batch 415]: seen 416000 tweets at 1646.7 tps, cost = 0.127
# [batch 417]: seen 418000 tweets at 1646.7 tps, cost = 0.127
# [batch 419]: seen 420000 tweets at 1646.5 tps, cost = 0.127
# [batch 421]: seen 422000 tweets at 1646.4 tps, cost = 0.127
# [batch 423]: seen 424000 tweets at 1646.3 tps, cost = 0.127
# [batch 425]: seen 426000 tweets at 1646.2 tps, cost = 0.127
# [batch 427]: seen 428000 tweets at 1646.1 tps, cost = 0.127
# [batch 429]: seen 430000 tweets at 1646.0 tps, cost = 0.127
# [batch 431]: seen 432000 tweets at 1646.0 tps, cost = 0.127
# [batch 433]: seen 434000 tweets at 1645.8 tps, cost = 0.127
# [batch 435]: seen 436000 tweets at 1645.7 tps, cost = 0.127
# [batch 437]: seen 438000 tweets at 1645.7 tps, cost = 0.127
# [batch 439]: seen 440000 tweets at 1645.8 tps, cost = 0.127
# [batch 441]: seen 442000 tweets at 1645.7 tps, cost = 0.127
# [batch 443]: seen 444000 tweets at 1645.7 tps, cost = 0.127
# [batch 445]: seen 446000 tweets at 1645.4 tps, cost = 0.127
# [batch 447]: seen 448000 tweets at 1644.8 tps, cost = 0.127
# [batch 449]: seen 450000 tweets at 1644.3 tps, cost = 0.127
# [batch 451]: seen 452000 tweets at 1643.8 tps, cost = 0.127
# [batch 453]: seen 454000 tweets at 1643.3 tps, cost = 0.127
# [batch 455]: seen 456000 tweets at 1642.6 tps, cost = 0.127
# [batch 457]: seen 458000 tweets at 1642.0 tps, cost = 0.127
# [batch 459]: seen 460000 tweets at 1641.5 tps, cost = 0.127
# [batch 461]: seen 462000 tweets at 1641.3 tps, cost = 0.127
# [batch 463]: seen 464000 tweets at 1641.3 tps, cost = 0.127
# [batch 465]: seen 466000 tweets at 1641.5 tps, cost = 0.127
# [batch 467]: seen 468000 tweets at 1641.6 tps, cost = 0.127
# [batch 469]: seen 470000 tweets at 1641.7 tps, cost = 0.127
# [batch 471]: seen 472000 tweets at 1641.2 tps, cost = 0.127
# [batch 473]: seen 474000 tweets at 1641.0 tps, cost = 0.127
# [batch 475]: seen 476000 tweets at 1640.7 tps, cost = 0.127
# [batch 477]: seen 478000 tweets at 1640.5 tps, cost = 0.127
# [batch 479]: seen 480000 tweets at 1640.4 tps, cost = 0.127
# [batch 481]: seen 482000 tweets at 1640.5 tps, cost = 0.127
# [batch 483]: seen 484000 tweets at 1640.4 tps, cost = 0.127
# [batch 485]: seen 486000 tweets at 1640.4 tps, cost = 0.127
# [batch 487]: seen 488000 tweets at 1640.5 tps, cost = 0.127
# [batch 489]: seen 490000 tweets at 1640.4 tps, cost = 0.127
# [batch 491]: seen 492000 tweets at 1640.3 tps, cost = 0.127
# [batch 493]: seen 494000 tweets at 1640.3 tps, cost = 0.127
# [batch 495]: seen 496000 tweets at 1640.3 tps, cost = 0.127
# [batch 497]: seen 498000 tweets at 1640.4 tps, cost = 0.127
# [batch 499]: seen 500000 tweets at 1640.5 tps, cost = 0.127
# [batch 501]: seen 502000 tweets at 1640.5 tps, cost = 0.127
# [batch 503]: seen 504000 tweets at 1640.4 tps, cost = 0.127
# [batch 505]: seen 506000 tweets at 1640.4 tps, cost = 0.127
# [batch 507]: seen 508000 tweets at 1640.4 tps, cost = 0.127
# [batch 509]: seen 510000 tweets at 1640.4 tps, cost = 0.127
# [batch 511]: seen 512000 tweets at 1640.4 tps, cost = 0.127
# [batch 513]: seen 514000 tweets at 1640.4 tps, cost = 0.127
# [batch 515]: seen 516000 tweets at 1640.3 tps, cost = 0.127
# [batch 517]: seen 518000 tweets at 1640.3 tps, cost = 0.127
# [batch 519]: seen 520000 tweets at 1640.2 tps, cost = 0.127
# [batch 521]: seen 522000 tweets at 1640.0 tps, cost = 0.127
# [batch 523]: seen 524000 tweets at 1640.0 tps, cost = 0.127
# [batch 525]: seen 526000 tweets at 1640.0 tps, cost = 0.127
# [batch 527]: seen 528000 tweets at 1640.1 tps, cost = 0.127
# [batch 529]: seen 530000 tweets at 1640.0 tps, cost = 0.127
# [batch 531]: seen 532000 tweets at 1640.1 tps, cost = 0.127
# [batch 533]: seen 534000 tweets at 1640.2 tps, cost = 0.127
# [batch 535]: seen 536000 tweets at 1640.3 tps, cost = 0.127
# [batch 537]: seen 538000 tweets at 1640.4 tps, cost = 0.127
# [batch 539]: seen 540000 tweets at 1640.6 tps, cost = 0.127
# [batch 541]: seen 542000 tweets at 1640.7 tps, cost = 0.127
# [batch 543]: seen 544000 tweets at 1640.9 tps, cost = 0.126
# [batch 545]: seen 546000 tweets at 1641.0 tps, cost = 0.126
# [batch 547]: seen 548000 tweets at 1641.1 tps, cost = 0.126
# [batch 549]: seen 550000 tweets at 1641.3 tps, cost = 0.126
# [batch 551]: seen 552000 tweets at 1641.5 tps, cost = 0.126
# [batch 553]: seen 554000 tweets at 1641.6 tps, cost = 0.126
# [batch 555]: seen 556000 tweets at 1641.7 tps, cost = 0.126
# [batch 557]: seen 558000 tweets at 1641.8 tps, cost = 0.126
# [batch 559]: seen 560000 tweets at 1641.9 tps, cost = 0.126
# [batch 561]: seen 562000 tweets at 1642.0 tps, cost = 0.126
# [batch 563]: seen 564000 tweets at 1642.0 tps, cost = 0.126
# [batch 565]: seen 566000 tweets at 1642.2 tps, cost = 0.126
# [batch 567]: seen 568000 tweets at 1642.3 tps, cost = 0.126
# [batch 569]: seen 570000 tweets at 1642.5 tps, cost = 0.126
# [batch 571]: seen 572000 tweets at 1642.5 tps, cost = 0.126
# [batch 573]: seen 574000 tweets at 1642.4 tps, cost = 0.126
# [batch 575]: seen 576000 tweets at 1642.3 tps, cost = 0.126
# [batch 577]: seen 578000 tweets at 1642.3 tps, cost = 0.126
# [batch 579]: seen 580000 tweets at 1642.4 tps, cost = 0.126
# [batch 581]: seen 582000 tweets at 1642.4 tps, cost = 0.126
# [batch 583]: seen 584000 tweets at 1642.3 tps, cost = 0.126
# [batch 585]: seen 586000 tweets at 1642.2 tps, cost = 0.126
# [batch 587]: seen 588000 tweets at 1642.2 tps, cost = 0.126
# [batch 589]: seen 590000 tweets at 1642.1 tps, cost = 0.126
# [batch 591]: seen 592000 tweets at 1642.1 tps, cost = 0.126
# [batch 593]: seen 594000 tweets at 1642.1 tps, cost = 0.126
# [batch 595]: seen 596000 tweets at 1642.1 tps, cost = 0.126
# [batch 597]: seen 598000 tweets at 1642.1 tps, cost = 0.126
# [batch 599]: seen 600000 tweets at 1642.1 tps, cost = 0.126
# [batch 601]: seen 602000 tweets at 1642.1 tps, cost = 0.126
# [batch 603]: seen 604000 tweets at 1642.1 tps, cost = 0.126
# [batch 605]: seen 606000 tweets at 1642.1 tps, cost = 0.126
# [batch 607]: seen 608000 tweets at 1642.2 tps, cost = 0.126
# [batch 609]: seen 610000 tweets at 1642.2 tps, cost = 0.126
# [batch 611]: seen 612000 tweets at 1642.2 tps, cost = 0.126
# [batch 613]: seen 614000 tweets at 1642.2 tps, cost = 0.126
# [batch 615]: seen 616000 tweets at 1642.2 tps, cost = 0.126
# [batch 617]: seen 618000 tweets at 1642.2 tps, cost = 0.126
# [batch 619]: seen 620000 tweets at 1642.1 tps, cost = 0.126
# [batch 621]: seen 622000 tweets at 1642.1 tps, cost = 0.126
# [batch 623]: seen 624000 tweets at 1642.0 tps, cost = 0.126
# [batch 625]: seen 626000 tweets at 1642.1 tps, cost = 0.126
# [batch 627]: seen 628000 tweets at 1642.0 tps, cost = 0.126
# [batch 629]: seen 630000 tweets at 1642.1 tps, cost = 0.126
# [batch 631]: seen 632000 tweets at 1642.2 tps, cost = 0.126
# [batch 633]: seen 634000 tweets at 1642.2 tps, cost = 0.126
# [batch 635]: seen 636000 tweets at 1642.3 tps, cost = 0.126
# [batch 637]: seen 638000 tweets at 1642.4 tps, cost = 0.126
# [batch 639]: seen 640000 tweets at 1642.5 tps, cost = 0.126
# [batch 641]: seen 642000 tweets at 1642.5 tps, cost = 0.126
# [batch 643]: seen 644000 tweets at 1642.6 tps, cost = 0.126
# [batch 645]: seen 646000 tweets at 1642.7 tps, cost = 0.126
# [batch 647]: seen 648000 tweets at 1642.8 tps, cost = 0.126
# [batch 649]: seen 650000 tweets at 1642.9 tps, cost = 0.126
# [batch 651]: seen 652000 tweets at 1642.9 tps, cost = 0.126
# [batch 653]: seen 654000 tweets at 1643.0 tps, cost = 0.126
# [batch 655]: seen 656000 tweets at 1643.0 tps, cost = 0.126
# [batch 657]: seen 658000 tweets at 1643.1 tps, cost = 0.126
# [batch 659]: seen 660000 tweets at 1643.2 tps, cost = 0.126
# [batch 661]: seen 662000 tweets at 1643.3 tps, cost = 0.126
# [batch 663]: seen 664000 tweets at 1643.4 tps, cost = 0.126
# [batch 665]: seen 666000 tweets at 1643.5 tps, cost = 0.126
# [batch 667]: seen 668000 tweets at 1643.5 tps, cost = 0.126
# [batch 669]: seen 670000 tweets at 1643.4 tps, cost = 0.126
# [batch 671]: seen 672000 tweets at 1643.4 tps, cost = 0.126
# [batch 673]: seen 674000 tweets at 1643.4 tps, cost = 0.126
# [batch 675]: seen 676000 tweets at 1643.4 tps, cost = 0.126
# [batch 677]: seen 678000 tweets at 1643.5 tps, cost = 0.126
# [batch 679]: seen 680000 tweets at 1643.4 tps, cost = 0.126
# [batch 681]: seen 682000 tweets at 1643.4 tps, cost = 0.126
# [batch 683]: seen 684000 tweets at 1643.4 tps, cost = 0.126
# [batch 685]: seen 686000 tweets at 1643.3 tps, cost = 0.126
# [batch 687]: seen 688000 tweets at 1643.2 tps, cost = 0.126
# [batch 689]: seen 690000 tweets at 1643.1 tps, cost = 0.126
# [batch 691]: seen 692000 tweets at 1643.1 tps, cost = 0.126
# [batch 693]: seen 694000 tweets at 1643.1 tps, cost = 0.126
# [batch 695]: seen 696000 tweets at 1643.1 tps, cost = 0.126
# [batch 697]: seen 698000 tweets at 1643.1 tps, cost = 0.126
# [batch 699]: seen 700000 tweets at 1643.1 tps, cost = 0.126
# [batch 701]: seen 702000 tweets at 1643.0 tps, cost = 0.126
# [batch 703]: seen 704000 tweets at 1643.0 tps, cost = 0.126
# [batch 705]: seen 706000 tweets at 1643.0 tps, cost = 0.126
# [batch 707]: seen 708000 tweets at 1643.0 tps, cost = 0.126
# [batch 709]: seen 710000 tweets at 1642.9 tps, cost = 0.126
# [batch 711]: seen 712000 tweets at 1642.9 tps, cost = 0.126
# [batch 713]: seen 714000 tweets at 1643.0 tps, cost = 0.126
# [batch 715]: seen 716000 tweets at 1643.0 tps, cost = 0.126
# [batch 717]: seen 718000 tweets at 1643.1 tps, cost = 0.126
# [batch 719]: seen 720000 tweets at 1643.1 tps, cost = 0.126
# [batch 721]: seen 722000 tweets at 1642.8 tps, cost = 0.126
# [batch 723]: seen 724000 tweets at 1642.3 tps, cost = 0.126
# [batch 725]: seen 726000 tweets at 1641.9 tps, cost = 0.126
# [batch 727]: seen 728000 tweets at 1642.0 tps, cost = 0.126
# [batch 729]: seen 730000 tweets at 1642.1 tps, cost = 0.126
# [batch 731]: seen 732000 tweets at 1642.1 tps, cost = 0.126
# [batch 733]: seen 734000 tweets at 1642.3 tps, cost = 0.126
# [batch 735]: seen 736000 tweets at 1642.4 tps, cost = 0.126

# %%
# Testing parameters
max_time = max_time
batch_size = 100
learning_rate = 0.00
num_epochs = 1
reload(lstm)
# Will print status every this many seconds
print_interval = 15

lm = lstm.RNNLM(**model_params)
lm.BuildCoreGraph()
lm.BuildTrainGraph()

with lm.graph.as_default():
    saver = tf.train.Saver()

y_pred=[]
y_true=[]
val_acc=[]
num_equals=[]
    
with tf.Session(graph=lm.graph) as session:
    saver.restore(session, trained_filename)
    
    for epoch in range(1,num_epochs+1):
        t0_epoch = time.time()
        bi = utils_proj.rnnlm_batch_generator(X_dev, batch_size, max_time,y_dev)
        print("[epoch {:d}] Starting epoch {:d}".format(epoch, epoch))
    
        for i, (w, y) in enumerate(bi):

            y_true.append(y)
            if i == 0:
                h = session.run(lm.initial_h_, {lm.input_w_: w})
            feed_dict = {
                lm.input_w_: w,
                lm.target_y_: y,
                lm.initial_h_: h,
            }
            ops = [lm.final_h_, lm.accuracy_,lm.predictions_,lm.num_equal_]        

            h,batch_acc,preds,num_equal = session.run(ops,feed_dict=feed_dict)

            val_acc.append(batch_acc)
            num_equals.append(num_equal)
           
            y_pred.append(preds)
            
            if i % 10 ==0:
                print("[epoch {:d}] Completed in {:s}".format(epoch, utils_proj.pretty_timedelta(since=t0_epoch)))
   
        print(batch_acc)

print('Test Accuracy :',round(np.mean(val_acc),2))
y_pred=np.round(y_pred)

# %%
print('Test Accuracy :',round(np.mean(val_acc),2))

# %%
cm=confusion_matrix(np.asarray(y_true).flatten(),y_pred.flatten())/len(y_pred.flatten())
plt.imshow(cm, interpolation='nearest',cmap=plt.cm.Blues)
plt.colorbar()
plt.xticks([0,1])
plt.yticks([0,1])
plt.ylabel('True label')
plt.xlabel('Predicted label')

fmt = '.2f' 
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" )

# %%
plt.hist(np.round(y_pred).flatten())
plt.title('Distribution of Predicted Sentiment')
